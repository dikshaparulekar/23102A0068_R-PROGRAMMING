# %% [markdown]
# Name : Diksha Parulekar.
# Roll no. : 23102A0068.

# %%
# !apt-get update -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install -y r-base
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.6.1-1.2204.1).
# 0 upgraded, 0 newly installed, 0 to remove and 134 not upgraded.

# %%
# !R --version
# Out:
# R version 4.6.1 (2026-06-24) -- "Happy Hop"
# Copyright (C) 2026 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under the terms of the
# GNU General Public License versions 2 or 3.
# For more information about these matters see
# https://www.gnu.org/licenses/.

# %% [markdown]
# 1. Addition of Two Vectors

# %%
# %%writefile test.R
# x <- c(2,3,5,7)
# y <- c(-2,-3,-5,8)
#
# print(x + y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1]  0  0  0 15

# %% [markdown]
# 2. Addition (Recycling Rule)

# %%
# %%writefile test.R
# x <- c(2,3,5,7)
# y <- c(8,9)
#
# print(x + y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 10 12 13 16

# %% [markdown]
# 3. Addition (Warning)

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
# y <- c(8,9,10)
#
# print(x + y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 10 12 15 15
# Warning message:
# In x + y : longer object length is not a multiple of shorter object length

# %% [markdown]
# 4. Subtraction

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
# y <- c(-2,-3,-5,8)
#
# print(x - y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1]  4  6 10 -1

# %% [markdown]
# 5. Subtraction (Recycling Rule)

# %%
# %%writefile test.R
#
# x <- c(12,13,15,17)
# y <- c(8,9)
#
# print(x - y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 4 4 7 8

# %% [markdown]
# 6. Subtraction (Warning)

# %%
# %%writefile test.R
#
# x <- c(12,13,15,17)
# y <- c(8,9,10)
#
# print(x - y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 4 4 5 9
# Warning message:
# In x - y : longer object length is not a multiple of shorter object length

# %% [markdown]
# 7. Multiplication

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
# y <- c(-2,-3,-5,8)
#
# print(x * y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1]  -4  -9 -25  56

# %% [markdown]
# 8. Multiplication (Recycling Rule)

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
# y <- c(8,9)
#
# print(x * y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 16 27 40 63

# %% [markdown]
# 9. Multiplication (Warning)

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
# y <- c(8,9,10)
#
# print(x * y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 16 27 50 56
# Warning message:
# In x * y : longer object length is not a multiple of shorter object length

# %% [markdown]
# 10. Division

# %%
# %%writefile test.R
#
# x <- c(24,20,8,16)
# y <- c(3,4,2,8)
#
# print(x / y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 8 5 4 2

# %% [markdown]
# 11. Division (Recycling Rule)

# %%
# %%writefile test.R
#
# x <- c(24,20,8,16)
# y <- c(4,2)
#
# print(x / y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1]  6 10  2  8

# %% [markdown]
# 12. Division (Warning)

# %%
# %%writefile test.R
#
# x <- c(24,20,8,16)
# y <- c(4,2,8)
#
# print(x / y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1]  6 10  1  4
# Warning message:
# In x/y : longer object length is not a multiple of shorter object length

# %% [markdown]
# 13. Assignment Operator

# %%
# %%writefile test.R
#
# x <- 20
# y <- x * 2
# z <- x + y
#
# print(x)
# print(y)
# print(z)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 20
# [1] 40
# [1] 60

# %% [markdown]
# 14. Assignment Using '='

# %%
# %%writefile test.R
#
# x = 20
# y = x * 2
# z = x + y
#
# print(x)
# print(y)
# print(z)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 20
# [1] 40
# [1] 60

# %% [markdown]
# 15. Character Assignment

# %%
# %%writefile test.R
#
# x <- "apple"
# y <- "banana"
#
# print(x)
# print(y)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] "apple"
# [1] "banana"

# %% [markdown]
# 16. Check Numeric and Character

# %%
# %%writefile test.R
#
# x <- 20
#
# print(is.numeric(x))
# print(is.character(x))
#
# y <- "apple"
#
# print(is.character(y))
# print(is.numeric(y))
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] FALSE

# %% [markdown]
# 17. Convert Number to Character

# %%
# %%writefile test.R
#
# x <- 20
#
# y <- as.character(x)
#
# print(y)
# print(is.character(y))
# print(is.numeric(y))
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] "20"
# [1] TRUE
# [1] FALSE

# %% [markdown]
# 18. Convert Character to Number

# %%
# %%writefile test.R
#
# y <- "apple"
#
# z <- as.numeric(y)
#
# print(z)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# Warning message:
# NAs introduced by coercion
# [1] NA

# %% [markdown]
# 19. Comments

# %%
# %%writefile test.R
#
# # This is a comment
#
# x <- 20
#
# print(x)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 20

# %% [markdown]
# 20. Case Sensitivity

# %%
# %%writefile test.R
#
# X <- 20
# x <- 10
#
# print(X)
# print(x)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 20
# [1] 10

# %% [markdown]
# 21. Create a Vector

# %%
# %%writefile test.R
#
# x <- c(1,2,3,4,5)
#
# print(x)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# 22. mode()

# %%
# %%writefile test.R
#
# x <- 6
# print(mode(x))
#
# y <- "apple"
# print(mode(y))
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] "numeric"
# [1] "character"

# %% [markdown]
# 23. storage.mode()

# %%
# %%writefile test.R
#
# x <- 6
# print(storage.mode(x))
#
# x <- TRUE
# print(storage.mode(x))
#
# x <- "apple"
# print(storage.mode(x))
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] "double"
# [1] "logical"
# [1] "character"

# %% [markdown]
# 24. Infinity

# %%
# %%writefile test.R
#
# print(3/0)
#
# x <- 5 + Inf
#
# print(is.finite(x))
# print(is.infinite(x))
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] Inf
# [1] FALSE
# [1] TRUE

# %% [markdown]
# 25. Scalar Addition

# %%
# %%writefile test.R
#
# print(2 + 3)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 5

# %% [markdown]
# 26. Scalar Multiplication

# %%
# %%writefile test.R
#
# print(2 * 3)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 6

# %% [markdown]
# 27. Scalar Subtraction

# %%
# %%writefile test.R
#
# print(2 - 3)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] -1

# %% [markdown]
# 28. Scalar Division

# %%
# %%writefile test.R
#
# print(3 / 2)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 1.5

# %% [markdown]
# 29. Mixed Expression

# %%
# %%writefile test.R
#
# print(2 * 3 - 4 + 5 / 6)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 2.833333

# %% [markdown]
# 30. BODMAS

# %%
# %%writefile test.R
#
# print((2 + 3) * 5 + 5 - 10)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 20

# %% [markdown]
# 31. Nested Brackets

# %%
# %%writefile test.R
#
# print((((2 + 3) * 5 + 5) - 10) / 2)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 10

# %% [markdown]
# 32. Blank Spaces

# %%
# %%writefile test.R
#
# print(2+5)
# print(2 +5)
# print(2+ 5)
# print(2 + 5)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 7
# [1] 7
# [1] 7
# [1] 7

# %% [markdown]
# 33. Add Scalar to Vector

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
#
# print(x + 10)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 12 13 15 17

# %% [markdown]
# 34. Subtract Scalar from Vector

# %%
# %%writefile test.R
#
# x <- c(12,13,15,17)
#
# print(x - 10)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 2 3 5 7

# %% [markdown]
# 35. Multiply Vector by Scalar

# %%
# %%writefile test.R
#
# x <- c(2,3,5,7)
#
# print(x * 10)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 20 30 50 70

# %% [markdown]
# 36. Divide Vector by Scalar

# %%
# %%writefile test.R
#
# x <- c(12,13,15,17)
#
# print(x / 10)
# Out:
# Overwriting test.R

# %%
# !Rscript test.R
# Out:
# [1] 1.2 1.3 1.5 1.7
